# %%
import pandas as pd

# %%
import glob
## Make a filepath query and use glob.glob to get COMPLETE filepaths
q = 'Data/final*.csv.gz'
file_list = sorted(glob.glob(q))
file_list
# Out:
# ['Data\\final_tmdb_data_2000.csv.gz',
#  'Data\\final_tmdb_data_2001.csv.gz',
#  'Data\\final_tmdb_data_2002.csv.gz',
#  'Data\\final_tmdb_data_2003.csv.gz',
#  'Data\\final_tmdb_data_2004.csv.gz',
#  'Data\\final_tmdb_data_2005.csv.gz',
#  'Data\\final_tmdb_data_2006.csv.gz',
#  'Data\\final_tmdb_data_2007.csv.gz',
#  'Data\\final_tmdb_data_2008.csv.gz',
#  'Data\\final_tmdb_data_2009.csv.gz',
#  'Data\\final_tmdb_data_2010.csv.gz',
#  'Data\\final_tmdb_data_2011.csv.gz',
#  'Data\\final_tmdb_data_2012.csv.gz',
#  'Data\\final_tmdb_data_2013.csv.gz',
#  'Data\\final_tmdb_data_2014.csv.gz',
#  'Data\\final_tmdb_data_2015.csv.gz',
#  'Data\\final_tmdb_data_2016.csv.gz',
#  'Data\\final_tmdb_data_2017.csv.gz',
#  'Data\\final_tmdb_data_2018.csv.gz',
#  'Data\\final_tmdb_data_2019.csv.gz',
#  'Data\\final_tmdb_data_2020.csv.gz',
#  'Data\\final_tmdb_data_2021.csv.gz']

# %%
df = pd.concat([pd.read_csv(f,lineterminator='\n') for f in file_list])
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg
# ...         ...    ...                               ...
# 3528  tt9895024    0.0   /S1kutYyoyuBJKGS0mXxv2fZNbr.jpg
# 3529  tt9896876    0.0  /hMvRbT6HOqERhh3K8kXbaLz9LlZ.jpg
# 3530  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 3531  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
# 3532  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN         0.0
# ...                    ...         ...
# 3528                   NaN         0.0
# 3529                   NaN         0.0
# 3530                   NaN         0.0
# 3531                   NaN         0.0
# 3532                   NaN         0.0
#
#                                                  genres homepage        id  \
# 0                                                   NaN      NaN       NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2              [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  442869.0
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  579396.0
# ...                                                 ...      ...       ...
# 3528  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  834443.0
# 3529  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  821493.0
# 3530                     [{'id': 27, 'name': 'Horror'}]      NaN  870671.0
# 3531  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN  861294.0
# 3532  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...      NaN  630392.0
#
#      original_language           original_title  ... runtime  \
# 0                  NaN                      NaN  ...     NaN
# 1                   en          The Fantasticks  ...    86.0
# 2                   en            For the Cause  ...   100.0
# 3                   hi                     Gang  ...   152.0
# 4                   hi                 Karobaar  ...   180.0
# ...                ...                      ...  ...     ...
# 3528                de              Heikos Welt  ...   118.0
# 3529                en  India Sweets and Spices  ...   101.0
# 3530                en              The Hunting  ...    91.0
# 3531                en             The Scrapper  ...    87.0
# 3532                en               The Cursed  ...   111.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# ...                                                 ...       ...
# 3528  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 3529  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3530  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3531  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3532  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                             tagline                    title  \
# 0                                               NaN                      NaN
# 1     Try to remember the first time magic happened          The Fantasticks
# 2      The ultimate showdown on a forbidden planet.            For the Cause
# 3                                               NaN                     Gang
# 4                              The Business of Love                 Karobaar
# ...                                             ...                      ...
# 3528                                            NaN            Heiko's World
# 3529                          Let the aunties talk.  India Sweets and Spices
# 3530                              Hunger runs deep.              The Hunting
# 3531                    You can't escape your past.             The Scrapper
# 3532                                            NaN               The Cursed
#
#      video  vote_average  vote_count certification\r certification
# 0      NaN           NaN         NaN              \r           NaN
# 1      0.0           5.5        22.0              \r           NaN
# 2      0.0           5.1         8.0              \r           NaN
# 3      0.0           4.0         1.0              \r           NaN
# 4      0.0           5.5         2.0              \r           NaN
# ...    ...           ...         ...             ...           ...
# 3528   0.0           0.0         0.0             NaN           NaN
# 3529   0.0           6.0         2.0             NaN         PG-13
# 3530   0.0           4.9        20.0             NaN           NaN
# 3531   0.0           6.0         2.0             NaN           NaN
# 3532   0.0           7.0        55.0             NaN             R
#
# [62327 rows x 27 columns]

# %%
df.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)
