# %%
import pandas as pd

# %%
basics = pd.read_csv("Data/title_basics.csv.gz")
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
ratings = pd.read_csv("Data/title_ratings.csv.gz")
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1947
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1773
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2580

# %%
tmdb = pd.read_csv("Data/tmdb_results_combined.csv.gz")
tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           5.5        2.0           NaN
#
# [5 rows x 26 columns]

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 3       tt0079644     movie
# 4       tt0088751     movie
# ...           ...       ...
# 137041  tt9916170     movie
# 137042  tt9916190     movie
# 137043  tt9916270     movie
# 137044  tt9916362     movie
# 137045  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                           November 1828
# 4                                       The Naked Monster
# ...                                                   ...
# 137041                                      The Rehearsal
# 137042                                          Safeguard
# 137043                           Il talento del calabrone
# 137044                                              Coven
# 137045                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0     2001.0
# 1       El tango del viudo y su espejo deformante        0     2020.0
# 2                      The Other Side of the Wind        0     2018.0
# 3                                   November 1828        0     2001.0
# 4                               The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 137041                                   O Ensaio        0     2019.0
# 137042                                  Safeguard        0     2020.0
# 137043                   Il talento del calabrone        0     2020.0
# 137044                                   Akelarre        0     2020.0
# 137045                        Kuambil Lagi Hatiku        0     2019.0
#
#         endYear  runtimeMinutes                     genres  \
# 0           NaN             118     Comedy,Fantasy,Romance
# 1           NaN              70                      Drama
# 2           NaN             122                      Drama
# 3           NaN             140                  Drama,War
# 4           NaN             100       Comedy,Horror,Sci-Fi
# ...         ...             ...                        ...
# 137041      NaN              51                      Drama
# 137042      NaN              95  Action,Adventure,Thriller
# 137043      NaN              84                   Thriller
# 137044      NaN              92              Drama,History
# 137045      NaN             123                      Drama
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3                        [Drama, War]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 137041                        [Drama]
# 137042  [Action, Adventure, Thriller]
# 137043                     [Thriller]
# 137044               [Drama, History]
# 137045                        [Drama]
#
# [137046 rows x 10 columns]

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 0       tt0035423     movie
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# ...           ...       ...
# 137042  tt9916190     movie
# 137043  tt9916270     movie
# 137044  tt9916362     movie
# 137044  tt9916362     movie
# 137045  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# ...                                                   ...
# 137042                                          Safeguard
# 137043                           Il talento del calabrone
# 137044                                              Coven
# 137044                                              Coven
# 137045                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0     2001.0
# 0                                  Kate & Leopold        0     2001.0
# 0                                  Kate & Leopold        0     2001.0
# 1       El tango del viudo y su espejo deformante        0     2020.0
# 2                      The Other Side of the Wind        0     2018.0
# ...                                           ...      ...        ...
# 137042                                  Safeguard        0     2020.0
# 137043                   Il talento del calabrone        0     2020.0
# 137044                                   Akelarre        0     2020.0
# 137044                                   Akelarre        0     2020.0
# 137045                        Kuambil Lagi Hatiku        0     2019.0
#
#         endYear  runtimeMinutes                     genres genres_split
# 0           NaN             118     Comedy,Fantasy,Romance       Comedy
# 0           NaN             118     Comedy,Fantasy,Romance      Fantasy
# 0           NaN             118     Comedy,Fantasy,Romance      Romance
# 1           NaN              70                      Drama        Drama
# 2           NaN             122                      Drama        Drama
# ...         ...             ...                        ...          ...
# 137042      NaN              95  Action,Adventure,Thriller     Thriller
# 137043      NaN              84                   Thriller     Thriller
# 137044      NaN              92              Drama,History        Drama
# 137044      NaN              92              Drama,History      History
# 137045      NaN             123                      Drama        Drama
#
# [238612 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
basics['genre_id'] = basics['genres_split'].replace(genre_map)
basics = basics.drop(columns='genres_split')

# %%
genre_lookup = pd.DataFrame({'Genre_Name':genre_id_map.keys(),
                             'Genre_ID':genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
basics = basics.drop(columns=['originalTitle','isAdult','titleType','genres'])
basics.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0079644                                      November 1828     2001.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#    endYear  runtimeMinutes                    genre_id
# 0      NaN             118  [Comedy, Fantasy, Romance]
# 1      NaN              70                     [Drama]
# 2      NaN             122                     [Drama]
# 3      NaN             140                [Drama, War]
# 4      NaN             100    [Comedy, Horror, Sci-Fi]

# %%
tmdb = tmdb[['imdb_id','budget','revenue','certification']].copy()
tmdb.head()
# Out:
#      imdb_id      budget  revenue certification
# 0          0         NaN      NaN           NaN
# 1  tt0113026  10000000.0      0.0           NaN
# 2  tt0113092         0.0      0.0           NaN
# 3  tt0116391         0.0      0.0           NaN
# 4  tt0116748         0.0      0.0           NaN
