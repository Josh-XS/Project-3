# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')

# %%
df2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
df2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg                   NaN
# 3  tt0089067    0.0                               NaN                   NaN
# 4  tt0114447    0.0                               NaN                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0                     [{'id': 10752, 'name': 'War'}]      NaN
# 3         0.0                     [{'id': 35, 'name': 'Comedy'}]      NaN
# 4         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
#
# ...

# %%
df = pd.concat([df2000,df2001])
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
valid_budget_revenue = len(df[(df['budget']>0) & (df['revenue']>0)])
print(valid_budget_revenue)
vbr_df = df[(df['budget']>0) & (df['revenue']>0)]
# Out:
# 375

# %%
vbr_df['certification'].value_counts()
# Out:
# R        144
# PG-13    117
# PG        30
# G         13
# NR         6
# Name: certification, dtype: int64

# %%
vbr_df['certification'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
vbr_df.groupby('certification', as_index=False)['revenue'].mean()
# Out:
#   certification       revenue
# 0             G  1.332169e+08
# 1            NR  2.382332e+07
# 2            PG  1.304904e+08
# 3         PG-13  1.110740e+08
# 4             R  5.230737e+07

# %%
vbr_df.groupby('certification', as_index=False)['revenue'].mean().plot(kind='bar')
plt.xlabel('certification')
# Out:
# Text(0.5, 0, 'certification')

# %%
vbr_df.groupby('certification', as_index=False)['budget'].mean()
# Out:
#   certification        budget
# 0             G  4.400000e+07
# 1            NR  1.478333e+07
# 2            PG  5.218333e+07
# 3         PG-13  4.680682e+07
# 4             R  2.695496e+07

# %%
vbr_df.groupby('certification', as_index=False)['budget'].mean().plot(kind='bar')
plt.xlabel('certification')
# Out:
# <AxesSubplot: >

# %%
df.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)
