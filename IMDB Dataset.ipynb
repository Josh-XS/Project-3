# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
#ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'
#akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'

# %%
#basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
#ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
#akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Basics

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9569610 entries, 0 to 9569609
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 657.1+ MB

# %%
basics.replace({'\\N':np.nan},inplace=True)
basics.dropna(subset=['runtimeMinutes','genres','startYear'],inplace=True)

# %%
basics['runtimeMinutes'].isnull().values.any()
# Out:
# False

# %%
basics['genres'].isnull().values.any()
# Out:
# False

# %%
basics['startYear'].isnull().values.any()
# Out:
# False

# %%
basics.isnull().values.any()
# Out:
# True

# %%
is_movie = basics['titleType'].str.contains('movie')
basics = basics[is_movie]

basics['startYear'] = basics['startYear'].astype(float).copy()
basics = basics[(basics['startYear']>=2000)&(basics['startYear']<2022)]

is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
keepers =basics['tconst'].isin(akas['titleId'])

# %%
basics = basics[keepers]

# %%
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9569283  tt9916170     movie
# 9569292  tt9916190     movie
# 9569331  tt9916270     movie
# 9569376  tt9916362     movie
# 9569460  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 86801                                    The Naked Monster
# ...                                                    ...
# 9569283                                      The Rehearsal
# 9569292                                          Safeguard
# 9569331                           Il talento del calabrone
# 9569376                                              Coven
# 9569460                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0     2001.0     NaN
# 61116    El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67669                   The Other Side of the Wind       0     2018.0     NaN
# 77964                                November 1828       0     2001.0     NaN
# 86801                            The Naked Monster       0     2005.0     NaN
# ...                                            ...     ...        ...     ...
# 9569283                                   O Ensaio       0     2019.0     NaN
# 9569292                                  Safeguard       0     2020.0     NaN
# 9569331                   Il talento del calabrone       0     2020.0     NaN
# 9569376                                   Akelarre       0     2020.0     NaN
# 9569460                        Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 77964              140                  Drama,War
# 86801              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9569283             51                      Drama
# 9569292             95  Action,Adventure,Thriller
# 9569331             84                   Thriller
# 9569376             92              Drama,History
# 9569460            123                      Drama
#
# [137046 rows x 9 columns]

# %% [markdown]
# ## Ratings

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1947
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1773
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2580

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273684 entries, 0 to 1273683
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1273684 non-null  object
#  1   averageRating  1273684 non-null  float64
#  2   numVotes       1273684 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.2+ MB

# %%
ratings.replace({'\\N':np.nan})
keepers2 =ratings['tconst'].isin(akas['titleId'])
ratings = ratings[keepers2]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1947
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1773
# 3        tt0000004            5.6       179
# 4        tt0000005            6.2      2580
# ...            ...            ...       ...
# 1273666  tt9916460            9.4        18
# 1273668  tt9916538            8.3         6
# 1273669  tt9916544            6.9        61
# 1273679  tt9916730            8.1         9
# 1273680  tt9916766            7.0        21
#
# [955686 rows x 3 columns]

# %% [markdown]
# ## AKAS

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34716118 entries, 0 to 34716117
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB

# %%
akas.replace({'\\N':np.nan})
akas.dropna(subset=['region'],inplace=True)
in_US = akas['region'].str.contains('US',case=False)
akas = akas[in_US]

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 34715645  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 34715715  tt9916620         1                          The Copeland Case
# 34715803  tt9916702         1              Loving London: The Playground
# 34715846  tt9916756         1                   Pretty Pretty Black Girl
# 34715862  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 34715645     US       \N  imdbDisplay                     \N               0
# 34715715     US       \N           \N                     \N               0
# 34715803     US       \N           \N                     \N               0
# 34715846     US       \N  imdbDisplay                     \N               0
# 34715862     US       \N  imdbDisplay                     \N               0
#
# [1409292 rows x 8 columns]

# %% [markdown]
# # Saving the Data to a Folder

# %%
import os
os.makedirs('Data/',exist_ok=True)
os.listdir("Data/")
# Out:
# []

# %%
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1947
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1773
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2580

# %%
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0
